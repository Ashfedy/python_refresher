# %% [markdown]
# # Dataframe

# %%
import pandas as pd
import numpy as np

# %%
# creating an array

# 1st way of creating an array
# data = np.array([["Ashwin",32],["Niveda",33],["Julia",23]])

# 2nd way of creating an array
data = [["Ashwin",32],["Niveda",33],["Jayanthi",59],["Julia",23],["Aravinth",32]]

# %%
# creating a dataframe
df = pd.DataFrame(data,index=['1','2','3','4','5'],columns=['Name','Age'])

# %%
# display dataframe
df
# Out:
#        Name  Age
# 1    Ashwin   32
# 2    Niveda   33
# 3  Jayanthi   59
# 4     Julia   23
# 5  Aravinth   32
